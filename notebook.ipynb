# %%
numeros = [1, 2, 3, 4, 5, 6]
pares_ao_quadrado = []
for n in numeros:
if n % 2 == 0:
pares_ao_quadrado.append(n ** 2)

print(pares_ao_quadrado)

# %%
numeros = [1, 2, 3, 4, 5, 6]

pares_ao_quadrado = [n ** 2 for n in numeros if n % 2 == 0]

print(pares_ao_quadrado)
